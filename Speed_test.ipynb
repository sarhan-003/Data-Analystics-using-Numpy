# %%
#Python Zip Explained
l1 = [1,2,4]
l2 = [6,7,8]
list(zip(l1,l2))
# Out:
# [(1, 6), (2, 7), (4, 8)]

# %%
#Using Python lists 
import numpy as np

# %%
# Using Python Lists
import numpy as np
import time

size = 1_000_000_0

l1 = list(range(size))
l2 = list(range(size))

start = time.time()
add = [x+y for x,y in zip(l1, l2)]
end = time.time()
print(add[0:10])

print(end - start)
